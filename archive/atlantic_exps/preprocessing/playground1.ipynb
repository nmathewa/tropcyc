# %%
import pandas as pd

dir_ib = '/home/nmathewa/main/GIT/tropcyc/atlantic_exps/Datasets/'

# %%
dft_ib = pd.read_csv(dir_ib + 'ibtracs.NA.list.v04r00.csv')
# Out:
# /tmp/ipykernel_18527/4044007448.py:1: DtypeWarning: Columns (1,2,3,8,9,14,19,20,23,24,161,162) have mixed types. Specify dtype option on import or set low_memory=False.
#   dft_ib = pd.read_csv(dir_ib + 'ibtracs.NA.list.v04r00.csv')

# %%
dft_ib.head()
# Out:
#              SID SEASON NUMBER BASIN SUBBASIN       NAME             ISO_TIME  \
# 0                  Year
# 1  1851175N26270   1851      5   NaN       GM  NOT_NAMED  1851-06-23 12:00:00
# 2  1851175N26270   1851      5   NaN       GM  NOT_NAMED  1851-06-23 15:00:00
# 3  1851175N26270   1851      5   NaN       GM  NOT_NAMED  1851-06-23 18:00:00
# 4  1851175N26270   1851      5   NaN       GM  NOT_NAMED  1851-06-23 21:00:00
#
#   NATURE            LAT           LON  ... BOM_GUST_PER REUNION_GUST  \
# 0         degrees_north  degrees_east  ...       second          kts
# 1     TS        26.1000      -90.4000  ...
# 2     TS        26.2001      -90.6999  ...
# 3     TS        26.3000      -91.0000  ...
# 4     TS        26.3999      -91.3001  ...
#
#   REUNION_GUST_PER USA_SEAHGT USA_SEARAD_NE USA_SEARAD_SE USA_SEARAD_SW  \
# 0           second         ft         nmile         nmile         nmile
# 1
# 2
# 3
# 4
#
#   USA_SEARAD_NW STORM_SPEED STORM_DIR
# ...

# %%
months = ['08','09','10','11','12']

#dft_ib['ISO_TIME'] = pd.to_datetime(dft_ib['ISO_TIME'])
# Out:
# /tmp/ipykernel_18527/423090698.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dft_ib['ISO_TIME'] = pd.to_datetime(dft_ib['ISO_TIME'])
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# Cell In[9], line 3
#       1 months = ['08','09','10','11','12']
# ----> 3 dft_ib['ISO_TIME'] = pd.to_datetime(dft_ib['ISO_TIME'])
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1050, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1048         result = arg.map(cache_array)
#    1049     else:
# -> 1050         values = convert_listlike(arg._values, format)
#    1051         result = arg._constructor(values, index=arg.index, name=arg.name)
# ...
